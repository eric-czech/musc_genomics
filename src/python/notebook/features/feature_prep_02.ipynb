# %%
# %run -m ipy_startup
# %run -m ipy_logging
# %matplotlib inline
from musc_genomics import data
pd.set_option('max_info_rows', 10000)

# %%
d_raw = data.load('prepared', 'modeling_data_raw_02')
# Out:
# 2016-08-06 19:04:46,270:DEBUG:research.project.manager: Loading saved data from location "/Users/eczech/data/research/musc_genomics/prepared/modeling_data_raw_02.pkl"

# %%
d_raw.filter(regex='^RES:|^CL:').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 642 entries, 22RV1 to ZR7530
# Columns: 259 entries, CL:CANCER_TYPE to RES:p53 pathway:MDMX:NSC-207895
# dtypes: float64(252), object(7)
# memory usage: 1.3+ MB

# %%
d_raw.filter(regex='^RES:').head()
# Out:
# FEATURE  RES:CANCER_TYPE                RES:SITE RES:HISTOLOGY  \
# TUMOR_ID
# 22RV1               PRAD                prostate     carcinoma
# 2313287             STAD                 stomach     carcinoma
# 42MGBA               GBM  central_nervous_system        glioma
# 5637                BLCA           urinary_tract     carcinoma
# 639V                BLCA           urinary_tract     carcinoma
#
# FEATURE   RES:ABL signaling:ABL:AP-24534  RES:ABL signaling:ABL:Nilotinib  \
# TUMOR_ID
# 22RV1                           2.429741                         3.645934
# 2313287                         1.858713                         3.378428
# 42MGBA                         -1.441932                         1.505494
# 5637                            0.359716                         2.956437
# 639V                            0.063226                         2.449416
#
# FEATURE   RES:ABL signaling:ABL (T315I):GNF-2  \
# TUMOR_ID
# 22RV1                                     NaN
# 2313287                                   NaN
# 42MGBA                                    NaN
# 5637                                      NaN
# 639V                                      NaN
#
# FEATURE   RES:ABL signaling:ABL, KIT, PDGFR:Imatinib  \
# TUMOR_ID
# 22RV1                                            NaN
# 2313287                                          NaN
# 42MGBA                                           NaN
# 5637                                             NaN
# 639V                                             NaN
#
# FEATURE   RES:ABL signaling:ABL, SRC, KIT, PDGFR:Dasatinib  \
# TUMOR_ID
# 22RV1                                                  NaN
# 2313287                                                NaN
# 42MGBA                                                 NaN
# 5637                                                   NaN
# 639V                                                   NaN
#
# FEATURE   RES:ABL signaling:LOK, LTK, TRCB, ABL(T315I):HG-5-113-01  \
# TUMOR_ID
# 22RV1                                              1.683271
# 2313287                                                 NaN
# 42MGBA                                                  NaN
# 5637                                                    NaN
# 639V                                               1.609145
#
# FEATURE   RES:ABL signaling:SRC family, ABL:WH-4-023  \
# TUMOR_ID
# 22RV1                                            NaN
# 2313287                                          NaN
# 42MGBA                                           NaN
# 5637                                             NaN
# 639V                                             NaN
#
# FEATURE                ...                 RES:other:TIE2:KIN001-236  \
# TUMOR_ID               ...
# 22RV1                  ...                                  4.096331
# 2313287                ...                                  4.749415
# 42MGBA                 ...                                  4.132734
# 5637                   ...                                  4.579042
# 639V                   ...                                  4.417683
#
# FEATURE   RES:other:TNF alpha:Lenalidomide  \
# TUMOR_ID
# 22RV1                             4.454144
# 2313287                           4.292865
# 42MGBA                            3.587407
# 5637                              3.862487
# 639V                              2.437845
#
# FEATURE   RES:other:TPL2,COT(M3K8):KIN001-266  \
# TUMOR_ID
# 22RV1                                3.272366
# 2313287                              2.895975
# 42MGBA                               2.935137
# 5637                                 2.575704
# 639V                                 3.260532
#
# FEATURE   RES:other:gamma-secretase:BMS-708163  \
# TUMOR_ID
# 22RV1                                 3.650493
# 2313287                               4.050002
# 42MGBA                                4.184062
# 5637                                  4.110246
# 639V                                  4.041213
#
# FEATURE   RES:other:gamma-secretase:Z-LLNle-CHO  RES:other:unknown:FH535  \
# TUMOR_ID
# 22RV1                                       NaN                 1.101590
# 2313287                                     NaN                 1.296307
# 42MGBA                                      NaN                 3.751758
# 5637                                        NaN                 1.993463
# 639V                                        NaN                 0.604865
#
# FEATURE   RES:other:unknown:Shikonin  RES:p53 pathway:MDM2:JNJ-26854165  \
# TUMOR_ID
# 22RV1                       1.203081                           2.835527
# 2313287                     0.261285                           2.493011
# 42MGBA                      0.643791                           1.671162
# 5637                        2.522932                           1.411154
# 639V                       -1.408402                           2.062012
#
# FEATURE   RES:p53 pathway:MDM2:Nutlin-3a (-)  RES:p53 pathway:MDMX:NSC-207895
# TUMOR_ID
# 22RV1                               2.403369                         3.704255
# 2313287                             2.906627                         3.111120
# 42MGBA                              4.320196                         5.724220
# 5637                                4.193885                         2.780774
# 639V                                2.699072                         2.423240
#
# [5 rows x 255 columns]

# %%
d_raw['CL:HISTOLOGY'].value_counts()
# Out:
# carcinoma                                                     411
# lymphoid_neoplasm                                              72
# malignant_melanoma                                             36
# haematopoietic_neoplasm                                        34
# glioma                                                         30
# neuroblastoma                                                  12
# unknown                                                        11
# rhabdomyosarcoma                                                6
# mesothelioma                                                    6
# osteosarcoma                                                    5
# ewings_sarcoma-peripheral_primitive_neuroectodermal_tumour      5
# primitive_neuroectodermal_tumour-medulloblastoma                3
# leiomyosarcoma                                                  2
# rhabdoid_tumour                                                 2
# sarcoma                                                         2
# fibrosarcoma                                                    1
# carcinoid-endocrine_tumour                                      1
# malignant_fibrous_histiocytoma-pleomorphic_sarcoma              1
# other                                                           1
# chondrosarcoma                                                  1
# Name: CL:HISTOLOGY, dtype: int64

# %%
c_idx = ['TUMOR_ID', 'RES:CANCER_TYPE', 'RES:SITE', 'RES:HISTOLOGY']
d = d_raw.reset_index()

# Ensure that all metadata values are currently non-null before pushing them
# into an index
assert np.all(d[c_idx].notnull())

d = d.set_index(c_idx)

d.iloc[:5, :5]
# Out:
# FEATURE                                                        CN:A1BG  \
# TUMOR_ID RES:CANCER_TYPE RES:SITE               RES:HISTOLOGY
# 22RV1    PRAD            prostate               carcinoma     -0.08084
# 2313287  STAD            stomach                carcinoma     -0.03310
# 42MGBA   GBM             central_nervous_system glioma         0.03220
# 5637     BLCA            urinary_tract          carcinoma     -0.03514
# 639V     BLCA            urinary_tract          carcinoma      0.08280
#
# FEATURE                                                        CN:A1BG-AS1  \
# TUMOR_ID RES:CANCER_TYPE RES:SITE               RES:HISTOLOGY
# 22RV1    PRAD            prostate               carcinoma         -0.08084
# 2313287  STAD            stomach                carcinoma         -0.03310
# 42MGBA   GBM             central_nervous_system glioma             0.03220
# 5637     BLCA            urinary_tract          carcinoma         -0.03514
# 639V     BLCA            urinary_tract          carcinoma          0.08280
#
# FEATURE                                                        CN:A1CF  \
# TUMOR_ID RES:CANCER_TYPE RES:SITE               RES:HISTOLOGY
# 22RV1    PRAD            prostate               carcinoma     -0.00250
# 2313287  STAD            stomach                carcinoma     -0.05348
# 42MGBA   GBM             central_nervous_system glioma        -0.05220
# 5637     BLCA            urinary_tract          carcinoma     -0.49350
# 639V     BLCA            urinary_tract          carcinoma      0.05900
#
# FEATURE                                                        CN:A2M  \
# TUMOR_ID RES:CANCER_TYPE RES:SITE               RES:HISTOLOGY
# 22RV1    PRAD            prostate               carcinoma      0.4486
# 2313287  STAD            stomach                carcinoma     -0.1917
# 42MGBA   GBM             central_nervous_system glioma        -0.3905
# 5637     BLCA            urinary_tract          carcinoma     -0.0657
# 639V     BLCA            urinary_tract          carcinoma      0.3126
#
# FEATURE                                                        CN:A2ML1
# TUMOR_ID RES:CANCER_TYPE RES:SITE               RES:HISTOLOGY
# 22RV1    PRAD            prostate               carcinoma        0.4486
# 2313287  STAD            stomach                carcinoma       -0.1917
# 42MGBA   GBM             central_nervous_system glioma          -0.3905
# 5637     BLCA            urinary_tract          carcinoma       -0.0657
# 639V     BLCA            urinary_tract          carcinoma        0.3126

# %% [markdown]
# ## Minimally Encoded Feature Set

# %%
from sklearn.preprocessing import LabelEncoder

d_encode_min = d.copy()
encoders = {}

# For each of the following non-numeric values, apply a label encoder
# and save that encoder in a map to eventually be attached to resulting data frame
c_encode = ['CL:PRIMARY_SITE', 'CL:CANCER_TYPE', 'CL:HISTOLOGY', 'CL:GENDER']
for c in c_encode:
    assert np.all(d_encode_min[c].notnull()), 'Categorical variable "{}" has null values'.format(c)
    encoders[c] = LabelEncoder().fit(d_encode_min[c].values)
    d_encode_min[c] = encoders[c].transform(d_encode_min[c]).astype(np.float64)
d_encode_min.label_encoders = encoders

# Ensure that all features have been encoded in some numeric form at this point
assert np.all(d_encode_min.dtypes == np.float64), 'Some features are still not floating point values'

# %%
d_encode_min.filter(regex='^CL:').describe().T
# Out:
#                  count      mean       std  min  25%   50%   75%   max
# FEATURE
# CL:CANCER_TYPE   642.0  0.852025  0.400745  0.0  1.0   1.0   1.0   2.0
# CL:HISTOLOGY     642.0  3.828660  4.409101  0.0  1.0   1.0   6.0  19.0
# CL:PRIMARY_SITE  642.0  9.933022  5.589454  0.0  6.0  10.0  12.0  23.0
# CL:GENDER        642.0  0.700935  0.649708  0.0  0.0   1.0   1.0   2.0

# %%
data.save('features', 'encode_minimal_02', d_encode_min)
# Out:
# 2016-08-06 19:07:38,418:DEBUG:research.project.manager: Saving data to location "/Users/eczech/data/research/musc_genomics/features/encode_minimal_02.pkl"
# '/Users/eczech/data/research/musc_genomics/features/encode_minimal_02.pkl'

# %% [markdown]
# ## Maximally Encoded Feature Set

# %%
d_encode_max = d.copy()

# For each of the following non-numeric values, apply dummy encoding
c_encode = ['CL:PRIMARY_SITE', 'CL:CANCER_TYPE', 'CL:HISTOLOGY', 'CL:GENDER']
for c in c_encode:
    assert np.all(d_encode_max[c].notnull()), 'Categorical variable "{}" has null values'.format(c)
    
    d_encode_max = pd.concat([
        d_encode_max.drop(c, axis=1),
        pd.get_dummies(d_encode_max[c], prefix_sep=':', prefix=c)
    ], axis=1)

    # Remove "unknown" values?
    #     c_ref = c + ':unknown'
    #     if c_ref in d_encode_max:
    #         d_encode_max = d_encode_max.drop(c_ref, axis=1)
    
# Ensure that all features have been encoded in some numeric form at this point
assert np.all(d_encode_max.dtypes == np.float64), 'Some features are still not floating point values'

# %%
d_encode_max.iloc[:3, :5]
# Out:
# FEATURE                                                        CN:A1BG  \
# TUMOR_ID RES:CANCER_TYPE RES:SITE               RES:HISTOLOGY
# 22RV1    PRAD            prostate               carcinoma     -0.08084
# 2313287  STAD            stomach                carcinoma     -0.03310
# 42MGBA   GBM             central_nervous_system glioma         0.03220
#
# FEATURE                                                        CN:A1BG-AS1  \
# TUMOR_ID RES:CANCER_TYPE RES:SITE               RES:HISTOLOGY
# 22RV1    PRAD            prostate               carcinoma         -0.08084
# 2313287  STAD            stomach                carcinoma         -0.03310
# 42MGBA   GBM             central_nervous_system glioma             0.03220
#
# FEATURE                                                        CN:A1CF  \
# TUMOR_ID RES:CANCER_TYPE RES:SITE               RES:HISTOLOGY
# 22RV1    PRAD            prostate               carcinoma     -0.00250
# 2313287  STAD            stomach                carcinoma     -0.05348
# 42MGBA   GBM             central_nervous_system glioma        -0.05220
#
# FEATURE                                                        CN:A2M  \
# TUMOR_ID RES:CANCER_TYPE RES:SITE               RES:HISTOLOGY
# 22RV1    PRAD            prostate               carcinoma      0.4486
# 2313287  STAD            stomach                carcinoma     -0.1917
# 42MGBA   GBM             central_nervous_system glioma        -0.3905
#
# FEATURE                                                        CN:A2ML1
# TUMOR_ID RES:CANCER_TYPE RES:SITE               RES:HISTOLOGY
# 22RV1    PRAD            prostate               carcinoma        0.4486
# 2313287  STAD            stomach                carcinoma       -0.1917
# 42MGBA   GBM             central_nervous_system glioma          -0.3905

# %%
d_encode_max.filter(regex='^CL:').describe().T.head()
# Out:
#                                         count      mean       std  min  25%  \
# FEATURE
# CL:PRIMARY_SITE:autonomic_ganglia       642.0  0.018692  0.135539  0.0  0.0
# CL:PRIMARY_SITE:biliary_tract           642.0  0.001558  0.039467  0.0  0.0
# CL:PRIMARY_SITE:bone                    642.0  0.018692  0.135539  0.0  0.0
# CL:PRIMARY_SITE:breast                  642.0  0.071651  0.258110  0.0  0.0
# CL:PRIMARY_SITE:central_nervous_system  642.0  0.054517  0.227212  0.0  0.0
#
#                                         50%  75%  max
# FEATURE
# CL:PRIMARY_SITE:autonomic_ganglia       0.0  0.0  1.0
# CL:PRIMARY_SITE:biliary_tract           0.0  0.0  1.0
# CL:PRIMARY_SITE:bone                    0.0  0.0  1.0
# CL:PRIMARY_SITE:breast                  0.0  0.0  1.0
# CL:PRIMARY_SITE:central_nervous_system  0.0  0.0  1.0

# %%
data.save('features', 'encode_maximal_02', d_encode_max)
# Out:
# 2016-08-06 19:07:54,375:DEBUG:research.project.manager: Saving data to location "/Users/eczech/data/research/musc_genomics/features/encode_maximal_02.pkl"
# '/Users/eczech/data/research/musc_genomics/features/encode_maximal_02.pkl'

# %%
d_encode_max.filter(regex='Ab')
# Out:
# Empty DataFrame
# Columns: []
# Index: [(22RV1, PRAD, prostate, carcinoma), (2313287, STAD, stomach, carcinoma), (42MGBA, GBM, central_nervous_system, glioma), (5637, BLCA, urinary_tract, carcinoma), (639V, BLCA, urinary_tract, carcinoma), (647V, BLCA, urinary_tract, carcinoma), (697, unknown, haematopoietic_and_lymphoid_tissue, lymphoid_neoplasm), (769P, KIRC, kidney, carcinoma), (8305C, THCA, thyroid, carcinoma), (8505C, THCA, thyroid, carcinoma), (8MGBA, GBM, central_nervous_system, glioma), (A101D, SKCM, skin, malignant_melanoma), (A172, GBM, central_nervous_system, glioma), (A204, unknown, soft_tissue, rhabdomyosarcoma), (A2058, SKCM, skin, malignant_melanoma), (A253, unknown, salivary_gland, carcinoma), (A2780, UNABLE TO CLASSIFY, ovary, carcinoma), (A375, SKCM, skin, malignant_melanoma), (A3KAW, DLBC, haematopoietic_and_lymphoid_tissue, lymphoid_neoplasm), (A498, KIRC, kidney, carcinoma), (A4FUK, DLBC, haematopoietic_and_lymphoid_tissue, lymphoid_neoplasm), (A549, LUAD, lung, carcinoma), (A673, unknown, bone, Ewings_sarcoma-peripheral_primitive_neuroectodermal_tumour), (A704, KIRC, kidney, carcinoma), (ABC1, LUAD, lung, carcinoma), (ACHN, KIRC, kidney, carcinoma), (AGS, STAD, stomach, carcinoma), (ALLSIL, ALL, haematopoietic_and_lymphoid_tissue, lymphoid_neoplasm), (AM38, GBM, central_nervous_system, glioma), (AMO1, MM, haematopoietic_and_lymphoid_tissue, lymphoid_neoplasm), (AN3CA, UCEC, endometrium, carcinoma), (ASPC1, PAAD, pancreas, carcinoma), (AU565, BRCA, breast, carcinoma), (BCPAP, THCA, thyroid, carcinoma), (BECKER, GBM, central_nervous_system, glioma), (BEN, UNABLE TO CLASSIFY, lung, carcinoma), (BFTC905, BLCA, urinary_tract, carcinoma), (BFTC909, KIRC, kidney, carcinoma), (BHT101, THCA, thyroid, carcinoma), (BHY, HNSC, upper_aerodigestive_tract, carcinoma), (BICR22, HNSC, upper_aerodigestive_tract, carcinoma), (BICR31, HNSC, upper_aerodigestive_tract, carcinoma), (BL41, unknown, haematopoietic_and_lymphoid_tissue, lymphoid_neoplasm), (BL70, unknown, haematopoietic_and_lymphoid_tissue, lymphoid_neoplasm), (BT20, BRCA, breast, carcinoma), (BT474, BRCA, breast, carcinoma), (BT483, BRCA, breast, carcinoma), (BT549, BRCA, breast, carcinoma), (BV173, LCML, haematopoietic_and_lymphoid_tissue, haematopoietic_neoplasm), (BXPC3, PAAD, pancreas, carcinoma), (C2BBE1, COAD/READ, large_intestine, carcinoma), (C32, SKCM, skin, malignant_melanoma), (C3A, LIHC, liver, carcinoma), (CA46, unknown, haematopoietic_and_lymphoid_tissue, lymphoid_neoplasm), (CADOES1, unknown, bone, Ewings_sarcoma-peripheral_primitive_neuroectodermal_tumour), (CAKI1, KIRC, kidney, carcinoma), (CAL120, BRCA, breast, carcinoma), (CAL12T, UNABLE TO CLASSIFY, lung, carcinoma), (CAL148, BRCA, breast, carcinoma), (CAL27, HNSC, upper_aerodigestive_tract, carcinoma), (CAL29, BLCA, urinary_tract, carcinoma), (CAL33, HNSC, upper_aerodigestive_tract, carcinoma), (CAL51, BRCA, breast, carcinoma), (CAL54, KIRC, kidney, carcinoma), (CAL62, THCA, thyroid, carcinoma), (CAL78, unknown, bone, chondrosarcoma), (CAL851, BRCA, breast, carcinoma), (CALU3, LUAD, lung, carcinoma), (CALU6, LUAD, lung, carcinoma), (CAMA1, BRCA, breast, carcinoma), (CAOV3, OV, ovary, carcinoma), (CAOV4, OV, ovary, carcinoma), (CAPAN1, PAAD, pancreas, carcinoma), (CAPAN2, PAAD, pancreas, carcinoma), (CAS1, GBM, central_nervous_system, glioma), (CCFSTTG1, GBM, central_nervous_system, glioma), (CCK81, COAD/READ, large_intestine, carcinoma), (CFPAC1, PAAD, pancreas, carcinoma), (CGTHW1, THCA, thyroid, carcinoma), (CHAGOK1, UNABLE TO CLASSIFY, lung, carcinoma), (CHL1, SKCM, skin, malignant_melanoma), (CHP126, NB, autonomic_ganglia, neuroblastoma), (CHP212, NB, autonomic_ganglia, neuroblastoma), (CL11, COAD/READ, large_intestine, carcinoma), (CL34, COAD/READ, large_intestine, carcinoma), (CL40, COAD/READ, large_intestine, carcinoma), (CMK, LAML, haematopoietic_and_lymphoid_tissue, haematopoietic_neoplasm), (CMLT1, LCML, haematopoietic_and_lymphoid_tissue, haematopoietic_neoplasm), (COLO205, COAD/READ, large_intestine, carcinoma),  ...
#
# [642 rows x 0 columns]
